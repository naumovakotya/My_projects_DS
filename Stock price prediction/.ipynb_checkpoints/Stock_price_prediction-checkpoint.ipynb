# %% [markdown]
# # Предсказывание стоимости акций

# %% [markdown]
# **Задача**: Обучить несколько моделей и выбрать лучшую, которая будет предсказывать стоимость акции открытия на следующий день.
#
# Данная работа ещё в процессе. Ожидается добавление описания всех этапов, перевод на английский язык, а также новые попытки улучшения метрики.

# %% [markdown]
# ## Загрузка данных

# %%
# Загрузка необходимых библиотек
import warnings
import re
import os

import pandas as pd
import numpy as np
import yfinance as yf

import seaborn as sns
import matplotlib.pyplot as plt

import optuna
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import make_scorer
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

# %%
# настройки
warnings.filterwarnings("ignore")
optuna.logging.set_verbosity(optuna.logging.WARNING)
optuna.logging.disable_default_handler()

# константы
RANDOM_STATE = 42
TEST_SIZE = 0.3
# SCORE = 'f1_macro'

# %% [markdown]
# ### Functions

# %%
# функция для просмотра данных        
def data_review(data):
    print('ПЕРВЫЕ 5 СТРОЧЕК С ДАННЫМИ:')
    display(data.head())
    print(f'\nОБЩАЯ ИНФОРМАЦИЯ О ДАННЫХ:\n')
    data.info()
    print(f'\n\nКОЛИЧЕСТВО ПРОПУСКОВ В ДАННЫХ:\n\n{data.isna().sum()}\n')
    print(f'\nКОЛИЧЕСТВО ДУБЛИКАТОВ В ДАННЫХ - {data.duplicated().sum()}\n')
    print('\nСТАТИСТИКА ПО ЧИСЛОВЫМ СТОЛБЦАМ:')
    display(data.describe())

# %% [markdown]
# ### Загрузка и первичное знакомство с данными

# %%
# Загрузка данных для Apple (AAPL)
data = yf.download("AAPL", start="2010-01-01", end="2023-12-22", progress=False)
data_review(data)
# Out:
# ПЕРВЫЕ 5 СТРОЧЕК С ДАННЫМИ:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.447412  493729600
# 2010-01-05  7.664286  7.699643  7.616071  7.656429   6.458560  601904800
# 2010-01-06  7.656429  7.686786  7.526786  7.534643   6.355826  552160000
# 2010-01-07  7.562500  7.571429  7.466071  7.520714   6.344077  477131200
# 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.386255  447610800
# ОБЩАЯ ИНФОРМАЦИЯ О ДАННЫХ:
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3517 entries, 2010-01-04 to 2023-12-21
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3517 non-null   float64
#  1   High       3517 non-null   float64
#  2   Low        3517 non-null   float64
#  3   Close      3517 non-null   float64
#  4   Adj Close  3517 non-null   float64
#  5   Volume     3517 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 192.3 KB
#
#
# КОЛИЧЕСТВО ПРОПУСКОВ В ДАННЫХ:
#
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
#
#
# КОЛИЧЕСТВО ДУБЛИКАТОВ В ДАННЫХ - 0
#
#
# СТАТИСТИКА ПО ЧИСЛОВЫМ СТОЛБЦАМ:
#               Open         High          Low        Close    Adj Close  \
# count  3517.000000  3517.000000  3517.000000  3517.000000  3517.000000
# mean     59.693226    60.338451    59.078411    59.736781    57.446624
# std      55.195792    55.826254    54.620977    55.255587    55.388233
# min       6.870357     7.000000     6.794643     6.858929     5.785829
# 25%      19.645357    19.821428    19.375713    19.607857    16.959982
# 50%      32.275002    32.605000    32.075001    32.270000    28.952730
# 75%      90.175003    91.330002    89.144997    90.445000    88.130859
# max     198.020004   199.619995   197.000000   198.110001   197.144180
#
#              Volume
# count  3.517000e+03
# mean   2.425736e+08
# std    2.204799e+08
# min    2.404830e+07
# 25%    9.293600e+07
# 50%    1.527352e+08
# 75%    3.285268e+08
# max    1.880998e+09

# %% [markdown]
# Краткие пояснения, что за собой скрывают названия столбцов:
#
# 1. **Date**: Дата торгового дня.
#
# 2. **Open**: Цена открытия акций в начале торгового дня.
#
# 3. **High**: Самая высокая цена, достигнутая акциями в течение торгового дня.
#
# 4. **Low**: Самая низкая цена, достигнутая акциями в течение торгового дня.
#
# 5. **Close**: Цена закрытия акций в конце торгового дня (без учета корпоративных действий).
#
# 6. **Adj Close**: Скорректированная цена закрытия, которая учитывает все корпоративные действия, такие как выплата дивидендов, разделение акций и т. д.
#
# 7. **Volume**: Объем торгов, показывающий количество акций, которые были куплены и проданы в течение торгового дня.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Functions

# %%
def new_features(df, sma_periods=[3, 5, 10], target='High', max_lag=6):
    # Приведение всех столбцов к общему виду
    df = df.rename(columns={'Adj Close': 'Adj_Close'})
    
    # Создание базовых признаков (на базе разности)
    df['Open_High'] = df['Open'] - df['High']
    df['Open_Low'] = df['Open'] - df['Low']
    df['High_Low'] = df['High'] - df['Low']
    df['High_Close'] = df['High'] - df['Close']
    df['Low_Close'] = df['Low'] - df['Close']
    df['Close_Open'] = df['Close'] - df['Open']
    df['AdjClose_Open'] = df['Adj_Close'] - df['Open']
    df['AdjClose_Low'] = df['Adj_Close'] - df['Low']
    df['AdjClose_High'] = df['Adj_Close'] - df['High']
    df['AdjClose_Close'] = df['Adj_Close'] - df['Close']
    
    # Скользящие средние (SMA и EMA) и Волатильность
    for period in sma_periods:
        df[f'SMA_{period}'] = df[target].rolling(window=period).mean()
        df[f'EMA_{period}'] = df[target].ewm(span=period, adjust=False).mean()
        df[f'Volatility_{period}'] = df[target].rolling(window=period).std()
    
    # Процентные изменения
    df['Volume_Change'] = df['Volume'].pct_change()
    df['Price_Change'] = df[target].pct_change()
    
    # Добавление признаков тренда и сезонности
    df['Day_of_Week'] = df.index.dayofweek
#     df['Number_of_Week'] = df.index.isocalendar().week
    df['Month'] = df.index.month
    df['Quarter'] = df.index.quarter
                   
    # Добавление лаг-функций
    for lag in range(1, max_lag):
        df[f'Lag_{lag}'] = df[target].shift(lag)
    
    # Удаление строк с NaN значениями, которые появились из-за использования скользящих средних и других вычислений
    df.dropna(inplace=True)
    
    # Добавляем столбец с ценой максимума на следующий день
    df['Target'] = df[target].shift(-1)
    
    # Удаляем последние данные (так как они не имеют значения для 'Target')
    df = df[:-1]
    
    return df

# %% [markdown]
# ### Анализ данных

# %%
data = new_features(data)

# %%
data_review(data)
# Out:
# ПЕРВЫЕ 5 СТРОЧЕК С ДАННЫМИ:
#                 Open      High       Low     Close  Adj_Close     Volume  \
# Date
# 2010-01-15  7.533214  7.557143  7.352500  7.354643   6.203989  594067600
# 2010-01-19  7.440357  7.685357  7.401429  7.680000   6.478442  730007600
# 2010-01-20  7.675357  7.698214  7.482143  7.561786   6.378723  612152800
# 2010-01-21  7.574286  7.618214  7.400357  7.431071   6.268459  608154400
# 2010-01-22  7.385000  7.410714  7.041429  7.062500   5.957553  881767600
#
#             Open_High  Open_Low  High_Low  High_Close  ...  Price_Change  \
# Date                                                   ...
# 2010-01-15  -0.023929  0.180714  0.204643    0.202500  ...      0.005417
# 2010-01-19  -0.245000  0.038928  0.283928    0.005357  ...      0.016966
# 2010-01-20  -0.022857  0.193214  0.216071    0.136428  ...      0.001673
# 2010-01-21  -0.043928  0.173929  0.217857    0.187143  ...     -0.010392
# 2010-01-22  -0.025714  0.343571  0.369285    0.348214  ...     -0.027237
#
#             Day_of_Week  Month  Quarter     Lag_1     Lag_2     Lag_3  \
# Date
# 2010-01-15            4      1        1  7.516429  7.533214  7.491786
# 2010-01-19            1      1        1  7.557143  7.516429  7.533214
# 2010-01-20            2      1        1  7.685357  7.557143  7.516429
# 2010-01-21            3      1        1  7.698214  7.685357  7.557143
# 2010-01-22            4      1        1  7.618214  7.698214  7.685357
#
#                Lag_4     Lag_5    Target
# Date
# 2010-01-15  7.607143  7.571429  7.685357
# 2010-01-19  7.491786  7.607143  7.698214
# 2010-01-20  7.533214  7.491786  7.618214
# 2010-01-21  7.516429  7.533214  7.410714
# 2010-01-22  7.557143  7.516429  7.310714
#
# [5 rows x 36 columns]
# ОБЩАЯ ИНФОРМАЦИЯ О ДАННЫХ:
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3400 entries, 2010-01-15 to 2023-07-20
# Data columns (total 36 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Open            3400 non-null   float64
#  1   High            3400 non-null   float64
#  2   Low             3400 non-null   float64
#  3   Close           3400 non-null   float64
#  4   Adj_Close       3400 non-null   float64
#  5   Volume          3400 non-null   int64
#  6   Open_High       3400 non-null   float64
#  7   Open_Low        3400 non-null   float64
#  8   High_Low        3400 non-null   float64
#  9   High_Close      3400 non-null   float64
#  10  Low_Close       3400 non-null   float64
#  11  Close_Open      3400 non-null   float64
#  12  AdjClose_Open   3400 non-null   float64
#  13  AdjClose_Low    3400 non-null   float64
#  14  AdjClose_High   3400 non-null   float64
#  15  AdjClose_Close  3400 non-null   float64
#  16  SMA_3           3400 non-null   float64
#  17  EMA_3           3400 non-null   float64
#  18  Volatility_3    3400 non-null   float64
#  19  SMA_5           3400 non-null   float64
#  20  EMA_5           3400 non-null   float64
#  21  Volatility_5    3400 non-null   float64
#  22  SMA_10          3400 non-null   float64
#  23  EMA_10          3400 non-null   float64
#  24  Volatility_10   3400 non-null   float64
#  25  Volume_Change   3400 non-null   float64
#  26  Price_Change    3400 non-null   float64
#  27  Day_of_Week     3400 non-null   int32
#  28  Month           3400 non-null   int32
#  29  Quarter         3400 non-null   int32
#  30  Lag_1           3400 non-null   float64
#  31  Lag_2           3400 non-null   float64
#  32  Lag_3           3400 non-null   float64
#  33  Lag_4           3400 non-null   float64
#  34  Lag_5           3400 non-null   float64
#  35  Target          3400 non-null   float64
# dtypes: float64(32), int32(3), int64(1)
# memory usage: 943.0 KB
#
#
# КОЛИЧЕСТВО ПРОПУСКОВ В ДАННЫХ:
#
# Open              0
# High              0
# Low               0
# Close             0
# Adj_Close         0
# Volume            0
# Open_High         0
# Open_Low          0
# High_Low          0
# High_Close        0
# Low_Close         0
# Close_Open        0
# AdjClose_Open     0
# AdjClose_Low      0
# AdjClose_High     0
# AdjClose_Close    0
# SMA_3             0
# EMA_3             0
# Volatility_3      0
# SMA_5             0
# EMA_5             0
# Volatility_5      0
# SMA_10            0
# EMA_10            0
# Volatility_10     0
# Volume_Change     0
# Price_Change      0
# Day_of_Week       0
# Month             0
# Quarter           0
# Lag_1             0
# Lag_2             0
# Lag_3             0
# Lag_4             0
# Lag_5             0
# Target            0
# dtype: int64
#
#
# КОЛИЧЕСТВО ДУБЛИКАТОВ В ДАННЫХ - 0
#
#
# СТАТИСТИКА ПО ЧИСЛОВЫМ СТОЛБЦАМ:
#               Open         High          Low        Close    Adj_Close  \
# count  3400.000000  3400.000000  3400.000000  3400.000000  3400.000000
# mean     55.927403    56.547795    55.336852    55.969611    53.638628
# std      51.456740    52.091047    50.883079    51.520014    51.576406
# min       6.870357     7.000000     6.794643     6.858929     5.785829
# 25%      19.373125    19.556519    19.186429    19.369821    16.802332
# 50%      31.621250    31.826250    31.406250    31.627500    28.314429
# 75%      72.484373    74.540001    71.591251    73.179375    71.114502
# max     195.089996   198.229996   192.649994   195.100006   193.631927
#
#              Volume    Open_High     Open_Low     High_Low   High_Close  ...  \
# count  3.400000e+03  3400.000000  3400.000000  3400.000000  3400.000000  ...
# mean   2.477419e+08    -0.620393     0.590550     1.210943     0.578184  ...
# std    2.212238e+08     0.974871     0.987101     1.498694     0.992389  ...
# min    3.145820e+07   -10.270004     0.000000     0.045000     0.000000  ...
# 25%    9.649890e+07    -0.657497     0.090003     0.298215     0.082857  ...
# 50%    1.588328e+08    -0.245001     0.231965     0.532499     0.215000  ...
# 75%    3.347953e+08    -0.092499     0.596696     1.518126     0.559998  ...
# max    1.880998e+09     0.000000    10.589996    12.809998     8.949997  ...
#
#        Price_Change  Day_of_Week        Month      Quarter        Lag_1  \
# count   3400.000000  3400.000000  3400.000000  3400.000000  3400.000000
# mean       0.001076     2.025294     6.453529     2.482941    56.492221
# std        0.015199     1.398506     3.411671     1.111470    52.042496
# min       -0.095652     0.000000     1.000000     1.000000     7.000000
# 25%       -0.006727     1.000000     3.750000     1.750000    19.553393
# 50%        0.001003     2.000000     6.000000     2.000000    31.821250
# 75%        0.008675     3.000000     9.000000     3.000000    73.841875
# max        0.105065     4.000000    12.000000     4.000000   198.229996
#
#              Lag_2        Lag_3        Lag_4        Lag_5       Target
# count  3400.000000  3400.000000  3400.000000  3400.000000  3400.000000
# mean     56.436133    56.381181    56.326265    56.272263    56.602917
# std      51.992432    51.945361    51.898165    51.853310    52.138327
# min       7.000000     7.000000     7.000000     7.000000     7.000000
# 25%      19.552589    19.546786    19.531518    19.530178    19.560983
# 50%      31.815000    31.807500    31.803750    31.800000    31.850000
# 75%      73.527500    73.440001    73.420624    73.234375    74.784374
# max     194.479996   194.479996   194.479996   194.479996   198.229996
#
# [8 rows x 36 columns]

# %% [markdown]
# ## Обучение
# ### Functions

# %%
def optimize_df(df):
    """Уменьшение размерности датафрейма"""
    initial_memory = df.memory_usage(deep=True).sum()
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type == 'float64' or col_type == 'float32':
            # Проверяем, можно ли привести float к int
            if df[col].apply(float.is_integer).all():
                df[col] = pd.to_numeric(df[col], downcast='integer')
            else:
                df[col] = pd.to_numeric(df[col], downcast='float')
        
        elif col_type == 'int64' or col_type == 'int32':
            df[col] = pd.to_numeric(df[col], downcast='integer')
        
        elif col_type == 'object':
            num_unique_values = len(df[col].unique())
            num_total_values = len(df[col])
            if num_unique_values / num_total_values < 0.5:
                df[col] = df[col].astype('category')
        
        elif col_type == 'bool':
            df[col] = df[col].astype('int8')
    
    final_memory = df.memory_usage(deep=True).sum()
    memory_reduction = (initial_memory - final_memory) / initial_memory * 100
    
    print(f"Память до оптимизации: {initial_memory} байт")
    print(f"Память после оптимизации: {final_memory} байт")
    print(f"Сокращение памяти: {memory_reduction:.2f}%")
    
    return df

# %%
def plot_feature_importances(model, feature_names, model_name):
    """
    Функция для вывода важности признаков для модели.

    Parameters:
    model (sklearn model): Обученная модель.
    feature_names (list): Список названий признаков.
    model_name (str): Название модели.
    """
    if hasattr(model, 'feature_importances_'):
        importances = model.feature_importances_
    elif hasattr(model, 'coef_'):
        importances = model.coef_
    else:
        raise ValueError(f"Model {model_name} does not have feature importances or coefficients.")

    # Создание DataFrame для удобного отображения
    feature_importance_df = pd.DataFrame({
        'Feature': feature_names,
        'Importance': importances
    })
    feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
    
    # Построение графика
    plt.figure(figsize=(10, 6))
    sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
    plt.title(f'Feature Importances for best model - {model_name}')
    plt.show()

# %% [markdown]
# ### Подготовка к обучению

# %% [markdown]
# ### Train

# %% [markdown]
# ## Выбор лучшей модели

# %% [markdown]
# ## Выводы
